# %%
import numpy as np
import pandas as pd

import rdflib

# %% [markdown]
# # KG Creation example notebook

# %% [markdown]
# ## Read data dump

# %%
studies_df = pd.read_csv("./dataset.csv", sep=";")
studies_df.head()
# Out:
#                                                title  \
# 0  Verified modeling of a low pressure hydrogen p...
# 1  Effect of a spatially fluctuating heating of p...
# 2  Upscaling from single- to multi-filament diele...
# 3  The effect of oxygen admixture on the properti...
# 4  Modelling and experimental evidence of the cat...
#
#                                             abstract  \
# 0  A self-consistent ﬂuid model has been successf...
# 1  The work is concerned with the effect of a spa...
# 2  A study on the scalability of discharge charac...
# 3  This work presents the datasets of the results...
# 4  The lifetime of tungsten cathodes used in plas...
#
#                                              topic  \
# 0  Materials / Surfaces; Plasma Chemical Processes
# 1                             Materials / Surfaces
# 2                        Plasma Chemical Processes
# 3                        Plasma Chemical Processes
# 4        Materials / Surfaces; Welding / Switching
#
# ...

# %%
studies_df.describe()
# Out:
#                                                     title  \
# count                                                  30
# unique                                                 30
# top     Verified modeling of a low pressure hydrogen p...
# freq                                                    1
#
#                                                  abstract  \
# count                                                  29
# unique                                                 29
# top     A self-consistent ﬂuid model has been successf...
# freq                                                    1
#
#                             topic                    tags Group  \
# count                          30                      30    26
# unique                          7                      29    11
# top     Plasma Chemical Processes  GMAW; high-current arc   INP
# freq                            9                       2    14
#
# ...

# %% [markdown]
# ## Load ontology

# %%
qptdat = rdflib.Graph()
qptdat.parse ('../ontology/qptdat.ttl', format='ttl')
g
# Out:
# <Graph identifier=Nd73c95cd4421452e8650058c205089d4 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Create all plasma studies

# %% [markdown]
# ## Create related datatype properties
